# %%
library(repr)

options(repr.plot.width=22, repr.plot.height=10)

# %% [markdown]
# ### Loading in daily min temp data for 10 years

# %%
df = read.csv('daily-min-temperatures.csv')

# %%
# quick look at the head(5)
df[1:5,]
# Out:
#   Date       Temp
# 1 1981-01-01 20.7
# 2 1981-01-02 17.9
# 3 1981-01-03 18.8
# 4 1981-01-04 14.6
# 5 1981-01-05 15.8

# %%
plot(df)
# Out:
# plot without title

# %%
summary(df['Temp'])
# Out:
#       Temp
#  Min.   : 0.00
#  1st Qu.: 8.30
#  Median :11.00
#  Mean   :11.18
#  3rd Qu.:14.00
#  Max.   :26.30

# %%
length(df[,'Temp'])
# Out:
# [1] 3650

# %%
temp.acf = acf(df['Temp'], type='correlation', length(df[,'Temp']))
# Out:
# Plot with title “Temp”

# %%
temp.pacf <- acf(df['Temp'], type='partial', 365)
# Out:
# Plot with title “Series  df["Temp"]”

# %%
temp.arim.20 <- arima(df['Temp'], order=c(20,0,0))

# %%
temp.arim.20
# Out:
# Call:
# arima(x = df["Temp"], order = c(20, 0, 0))
#
# Coefficients:
#          ar1      ar2     ar3     ar4     ar5     ar6     ar7     ar8     ar9
#       0.5930  -0.0920  0.0515  0.0395  0.0411  0.0290  0.0454  0.0172  0.0401
# s.e.  0.0165   0.0192  0.0193  0.0193  0.0193  0.0193  0.0193  0.0193  0.0193
#         ar10    ar11    ar12    ar13    ar14    ar15    ar16    ar17    ar18
#       0.0006  0.0051  0.0230  0.0274  0.0029  0.0276  0.0098  0.0146  0.0403
# s.e.  0.0193  0.0193  0.0193  0.0193  0.0193  0.0193  0.0193  0.0193  0.0193
#          ar19    ar20  intercept
#       -0.0106  0.0436    11.1780
# s.e.   0.0193  0.0166     0.7643
#
# sigma^2 estimated as 5.77:  log likelihood = -8378.54,  aic = 16801.08
